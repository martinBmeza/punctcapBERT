# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
metadata = pd.read_parquet("../data/processed/train/metadata_train.parquet")

# %%
metadata
# Out:
#      original_instance_id              chunk_id  \
# 0                  QYSCPD  instQYSCPD_chunk0000
# 1                  QYSCPD  instQYSCPD_chunk0001
# 2                  QYSCPD  instQYSCPD_chunk0002
# 3                  PH5JCC  instPH5JCC_chunk0000
# 4                  PH5JCC  instPH5JCC_chunk0001
# ...                   ...                   ...
# 6018               03XWB1  inst03XWB1_chunk0037
# 6019               03XWB1  inst03XWB1_chunk0038
# 6020               03XWB1  inst03XWB1_chunk0039
# 6021               03XWB1  inst03XWB1_chunk0040
# 6022               03XWB1  inst03XWB1_chunk0041
#
#                                                    path  n_tokens  \
# 0     data/processed/train/train/instQYSCPD_chunk000...       128
# 1     data/processed/train/train/instQYSCPD_chunk000...       128
# 2     data/processed/train/train/instQYSCPD_chunk000...        94
# 3     data/processed/train/train/instPH5JCC_chunk000...       128
# ...
